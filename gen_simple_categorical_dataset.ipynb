# %%
import csv
import json
import os
import random

# %% [markdown]
# If you're using a JSON file, you can point to it in the code block below. Otherwise, use the second code block to fill out a dict that describes the dataset you're generating. Your data should look something like this:
# ```
# data_descriptor_json = {
#   "defaultLabelColumn": "recommendation", #the default label to be predicted
#   "fields": [
#     {
#       "id": "age", #whatever the field contains
#       "type": "categorical", #or continuous, or binary
#       "values": {
#         #if categorical or binary
#         "categories": [],
#         #if continuous:
#         "min": 0,
#         "max": 100
#       }
#     }
#    ]
# }
# ```

# %%
data_json_file = open('your_file.json')
data_descriptor_json = json.read(data_json_file)

# %%
data_descriptor_json = {
  "defaultLabelColumn": "decision",
  "fields": [
    {
      "id": "age",
      "type": "categorical",
      "values": {
        "categories": ["Under 18", "18-34", "35-60", "Over 60"]
      }
    },
    {
      "id": "gender",
      "type": "categorical",
      "values": {
        "categories": ["male", "female"]
      }
    },
    {
      "id": "race",
      "type": "categorical",
      "values": {
        "categories": ["White", "Black or African American", "Asian", "American Indian or Alaska Native", "Native Hawaiian or Pacific Islander"]
      }
    },
    {
      "id": "bleeding",
      "type": "categorical",
      "values": {
        "categories": ["yes", "no"]
      }
    },
    {
      "id": "shortness_of_breath",
      "type": "categorical",
      "values": {
        "categories": ["yes", "no"]
      }
    },
    {
      "id": "weight",
      "type": "categorical",
      "values": {
        "categories": ["under 100 lbs", "100-150 lbs", "150-200 lbs", "200-300 lbs", "Over 300 lbs"]
      }
    },
    {
      "id": "area_of_pain",
      "type": "categorical",
      "values": {
        "categories": ["head", "chest", "limb", "stomach"]
      }
    },
    {
      "id": "decision",
      "type": "categorical",
      "values": {
        "categories": ["priority", "normal", "return later"]
      }
    }
  ]
}

fields = data_descriptor_json['fields']
label = data_descriptor_json['defaultLabelColumn']

# %% [markdown]
# Here we set up our constants. Basically, we want to set up a relationship between potential categories and a label outcome.
# ```
# {
#  "defaultLabelColumn": "is_sick",
#  "fields": [
#      {
#          "id": "nose_status"
#          "type: "categorical"
#          "values": {
#          "categories": [
#          "runny", "bleeding", "dry", "exploded"
#          ]
#      },
#      {
#          "id": "is_sick"
#          "type: "categorical"
#          "values": {
#          "categories": [
#          "no", "maybe", "definitely", "extremely"
#          ]
#      },
#  }
# ```
#  And, as a rule, if a patient's nose is dry they're always fine but otherwise the worse symptoms they have the more likely they are to be sick, we can structure our correlation as follows, using values below 0.5 for negative correlation and above 0.5 for positive:
#
# ```
# correlation_values = {
#     #here we use the categories of outcome as keys:
#         "no": {
#             "freq": #how often this answer should occur
#             "correlated_fields": [{"name": "nose_status", "correlated_category_values": {"dry": 1, "exploded": 0}] # so if nose_status = dry, is_sick = "no, while if their nose has exploded they're definitely sick!
#         }
#      }
# ```

# %% [markdown]
# This block prints out a quick template for converting our values in order to set up our correlation relationships

# %%
label_values = []
for i in fields:
    if i['id'] == label:
        label_values = i['values']['categories']
        print("template_values = {")
        for k in i['values']['categories']:
            print('"%s": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},' % k)
        print("}}")
    else:
        print('field: ', i['id'])
        print('categories: ', i['values']['categories'])
# Out:
# field:  age
# categories:  ['Under 18', '18-34', '35-60', 'Over 60']
# field:  gender
# categories:  ['male', 'female']
# field:  race
# categories:  ['White', 'Black or African American', 'Asian', 'American Indian or Alaska Native', 'Native Hawaiian or Pacific Islander']
# field:  bleeding
# categories:  ['yes', 'no']
# field:  shortness_of_breath
# categories:  ['yes', 'no']
# field:  weight
# categories:  ['under 100 lbs', '100-150 lbs', '150-200 lbs', '200-300 lbs', 'Over 300 lbs']
# field:  area_of_pain
# categories:  ['head', 'chest', 'limb', 'stomach']
# template_values = {
# "priority": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},
# "normal": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},
# "return later": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},
# }}

# %%
correlation_values = {"priority": {"freq": 0.1, "correlated_fields": [{"name": "gender", "correlated_category_values": {"male": .75}}]},
"normal": {"correlated_fields": [{"name": "race", "correlated_category_values": {"White": .75, 'Black or African American': 0.3}}]},
"return later": {"correlated_fields": [{"name": "shortness_of_breath", "correlated_category_values": {"yes": .6, "no": .2}}]}
}

num_rows = 200 # the number of rows in our output dataset
outfile_name = 'medical_priority.csv' # the name of the file we're writing to, should end in '.csv'
print(json.dumps(correlation_values, indent=2))
# Out:
# {
#   "priority": {
#     "freq": 0.1,
#     "correlated_fields": [
#       {
#         "name": "gender",
#         "correlated_category_values": {
#           "male": 0.75
#         }
#       }
#     ]
#   },
#   "normal": {
#     "correlated_fields": [
#       {
#         "name": "race",
#         "correlated_category_values": {
#           "White": 0.75,
#           "Black or African American": 0.3
#         }
#       }
#     ]
#   },
#   "return later": {
#     "correlated_fields": [
#       {
#         "name": "shortness_of_breath",
#         "correlated_category_values": {
#           "yes": 0.6,
#           "no": 0.2
#         }
#       }
#     ]
#   }
# }

# %%
#write the file
with open(outfile_name, 'w') as outfile:
    writer = csv.writer(outfile, delimiter=',')
    headers = [field['id'] for field in data_descriptor_json['fields']]
    writer.writerow(headers)
    label_val_idx = headers.index(label)
    

        
    for i in range(num_rows):
        row = []
        #object to see how highly they're correlated with diff outcomes
        correlation_counter = {}
        negative_correlation_counter = {}
        for field in data_descriptor_json['fields']:
            field_name = field['id']
            if field_name == label:
                row.append('')
                continue
            values = field["values"]
            categories = values["categories"]
            random_num = random.random()
            random_choice = random.choice(categories)
            
            def check_frequency(choice, corr_vals, num, categories):

                if 'freq' in corr_vals[choice] and num > corr_vals[choice]['freq']:
                    new_choice = random.choice(categories)
                    new_val = corr_vals[choice]

                    return check_frequency(new_choice, corr_vals, num, categories)
                else:
                    return choice
            
            #check against correlation values and increment our relationship accordingly
            for key, value in correlation_values.items():
                for i in value["correlated_fields"]:
                    corr_vals = i['correlated_category_values']
                    if random_choice in corr_vals.keys():
                        if key not in correlation_counter or correlation_counter[key] < corr_vals[random_choice]:
                            if corr_vals[random_choice] > 0.5:
                                correlation_counter[key] = corr_vals[random_choice]
                        if key not in negative_correlation_counter or negative_correlation_counter[key] > corr_vals[random_choice]:
                            if corr_vals[random_choice] < 0.5:
                                negative_correlation_counter[key] = corr_vals[random_choice]
            row.append(random_choice)
        random_label = random.choice(label_values)
        random_number = random.random()
        decision = random_label
        for key, value in correlation_counter.items():
            if decision not in correlation_counter.keys():
                decision = key
            else:
                if correlation_counter[key] > correlation_counter[decision]:
                    decision = key
        trimmed_labels = label_values.copy()
        trimmed_labels.remove(decision)
        
        output = ''
        if decision in negative_correlation_counter and decision in correlation_counter:
            if 1 - negative_correlation_counter[decision] > correlation_counter[decision] and random_num < negative_correlation_counter[decision]:
                output = random.choice(trimmed_labels)
            else:
                if random_num < correlation_counter[decision]:
                    output = decision
                else:
                    output = random.choice(trimmed_labels)
        else:
            if decision in correlation_counter and random_num < correlation_counter[decision]:
                output = decision
            else:
                output = random.choice(trimmed_labels)
        print('initial output', output)
        output = check_frequency(decision, correlation_values, random_num, label_values)
        print('final output', output)
        row[label_val_idx] = output
        print('row, ', row)
        
            
                    
                

                            
                        
      #  writer.writerow(row)
# Out:
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'male', 'White', 'yes', 'yes', '150-200 lbs', 'chest', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Asian', 'no', 'yes', 'under 100 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', 'under 100 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'male', 'White', 'no', 'no', '150-200 lbs', 'stomach', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '150-200 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Asian', 'no', 'no', 'Over 300 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'Black or African American', 'yes', 'no', 'under 100 lbs', 'chest', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '200-300 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'Black or African American', 'yes', 'no', '200-300 lbs', 'stomach', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['18-34', 'male', 'American Indian or Alaska Native', 'no', 'no', '150-200 lbs', 'limb', 'priority']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', 'under 100 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'male', 'Black or African American', 'no', 'yes', '150-200 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '200-300 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'male', 'Asian', 'no', 'no', 'Over 300 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Black or African American', 'no', 'no', '200-300 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'male', 'American Indian or Alaska Native', 'no', 'yes', 'under 100 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Black or African American', 'no', 'no', 'under 100 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'no', 'Over 300 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'yes', 'no', '100-150 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'female', 'White', 'yes', 'no', '150-200 lbs', 'stomach', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'Black or African American', 'yes', 'yes', '150-200 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['18-34', 'male', 'Asian', 'no', 'no', '150-200 lbs', 'stomach', 'priority']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '200-300 lbs', 'head', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'White', 'yes', 'yes', '150-200 lbs', 'head', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'no', 'no', 'Over 300 lbs', 'head', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Black or African American', 'yes', 'no', 'Over 300 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'yes', '100-150 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '100-150 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'no', 'yes', '150-200 lbs', 'head', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'male', 'Black or African American', 'yes', 'no', '200-300 lbs', 'stomach', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'female', 'Asian', 'no', 'no', '100-150 lbs', 'chest', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Black or African American', 'no', 'yes', '150-200 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'White', 'yes', 'no', 'Over 300 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Asian', 'yes', 'no', '150-200 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'no', 'no', '100-150 lbs', 'chest', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '150-200 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'White', 'no', 'no', '100-150 lbs', 'head', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'Black or African American', 'no', 'no', '200-300 lbs', 'limb', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'yes', 'no', 'Over 300 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'Black or African American', 'no', 'no', '100-150 lbs', 'limb', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'White', 'no', 'yes', 'Over 300 lbs', 'stomach', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'female', 'Asian', 'no', 'no', 'under 100 lbs', 'head', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'female', 'White', 'no', 'yes', 'Over 300 lbs', 'limb', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Asian', 'yes', 'no', 'under 100 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'male', 'White', 'no', 'yes', '200-300 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '200-300 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '200-300 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'chest', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'female', 'White', 'no', 'no', '200-300 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'male', 'Asian', 'yes', 'yes', '100-150 lbs', 'head', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'Asian', 'no', 'no', '150-200 lbs', 'stomach', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'Asian', 'no', 'no', 'under 100 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'Black or African American', 'no', 'yes', '200-300 lbs', 'limb', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'male', 'Black or African American', 'no', 'no', 'under 100 lbs', 'head', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'White', 'yes', 'no', 'Over 300 lbs', 'head', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'stomach', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'female', 'White', 'yes', 'no', '200-300 lbs', 'head', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'female', 'White', 'yes', 'yes', 'under 100 lbs', 'limb', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Asian', 'yes', 'yes', 'Over 300 lbs', 'head', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '150-200 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'no', '100-150 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'Black or African American', 'no', 'no', 'Over 300 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '100-150 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'White', 'no', 'no', 'under 100 lbs', 'head', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'female', 'White', 'no', 'no', '100-150 lbs', 'head', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Black or African American', 'yes', 'yes', '200-300 lbs', 'stomach', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Black or African American', 'yes', 'yes', 'under 100 lbs', 'stomach', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Black or African American', 'no', 'no', '100-150 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Asian', 'no', 'yes', 'Over 300 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'Asian', 'yes', 'no', '100-150 lbs', 'limb', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'White', 'yes', 'yes', '100-150 lbs', 'chest', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'stomach', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Asian', 'yes', 'no', '200-300 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'no', 'Over 300 lbs', 'chest', 'priority']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', 'under 100 lbs', 'head', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', '200-300 lbs', 'chest', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'White', 'no', 'no', 'under 100 lbs', 'stomach', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'male', 'Asian', 'no', 'yes', 'under 100 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['Under 18', 'male', 'White', 'no', 'no', 'under 100 lbs', 'head', 'priority']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'male', 'Asian', 'yes', 'no', 'Over 300 lbs', 'head', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'female', 'White', 'yes', 'no', '100-150 lbs', 'limb', 'normal']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '150-200 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Black or African American', 'yes', 'yes', '200-300 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'Asian', 'yes', 'yes', 'Over 300 lbs', 'stomach', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Black or African American', 'yes', 'yes', '100-150 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '100-150 lbs', 'head', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', 'under 100 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '150-200 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '200-300 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '200-300 lbs', 'limb', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'Black or African American', 'no', 'yes', '200-300 lbs', 'stomach', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'yes', 'under 100 lbs', 'chest', 'priority']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Asian', 'no', 'yes', 'under 100 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Asian', 'yes', 'yes', '200-300 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'Black or African American', 'yes', 'no', 'under 100 lbs', 'stomach', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'male', 'White', 'no', 'no', '200-300 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', '200-300 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'Asian', 'yes', 'no', 'under 100 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['35-60', 'male', 'Black or African American', 'yes', 'yes', '150-200 lbs', 'stomach', 'priority']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Asian', 'yes', 'yes', '100-150 lbs', 'head', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Asian', 'no', 'no', '150-200 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'yes', 'no', '150-200 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', 'under 100 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', 'under 100 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', 'under 100 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'no', 'yes', 'Over 300 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '200-300 lbs', 'chest', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '150-200 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'American Indian or Alaska Native', 'no', 'yes', 'under 100 lbs', 'limb', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['Over 60', 'male', 'Black or African American', 'no', 'yes', '150-200 lbs', 'stomach', 'priority']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', 'Over 300 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'Black or African American', 'no', 'yes', 'under 100 lbs', 'head', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'male', 'Asian', 'no', 'no', '200-300 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'White', 'no', 'no', '100-150 lbs', 'limb', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# ...
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'Asian', 'no', 'no', 'Over 300 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'female', 'White', 'yes', 'no', 'under 100 lbs', 'limb', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '100-150 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Asian', 'yes', 'yes', '150-200 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', '200-300 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Asian', 'no', 'yes', 'under 100 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'stomach', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'yes', 'no', '100-150 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'male', 'Black or African American', 'no', 'no', '100-150 lbs', 'limb', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '150-200 lbs', 'limb', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '100-150 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '200-300 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'yes', 'no', 'under 100 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'male', 'White', 'yes', 'no', 'under 100 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'male', 'White', 'no', 'no', 'Over 300 lbs', 'head', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'male', 'White', 'yes', 'yes', '150-200 lbs', 'chest', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'male', 'White', 'yes', 'no', '200-300 lbs', 'head', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'American Indian or Alaska Native', 'yes', 'no', '150-200 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['35-60', 'female', 'White', 'yes', 'no', 'under 100 lbs', 'chest', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Asian', 'yes', 'no', '200-300 lbs', 'stomach', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'Black or African American', 'no', 'yes', 'under 100 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'female', 'American Indian or Alaska Native', 'no', 'yes', '150-200 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '100-150 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'White', 'yes', 'no', 'under 100 lbs', 'limb', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['35-60', 'male', 'Black or African American', 'no', 'no', '100-150 lbs', 'chest', 'priority']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'limb', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['35-60', 'male', 'Black or African American', 'yes', 'yes', '150-200 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['Under 18', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'Over 300 lbs', 'limb', 'priority']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'female', 'White', 'no', 'no', 'Over 300 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Asian', 'yes', 'no', '100-150 lbs', 'stomach', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '150-200 lbs', 'head', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  priority
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'Over 300 lbs', 'limb', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '200-300 lbs', 'stomach', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  return later
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '100-150 lbs', 'limb', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'chest', 'return later']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# new choice:  normal
# new val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'male', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'no', 'no', '150-200 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['18-34', 'female', 'Black or African American', 'no', 'no', '200-300 lbs', 'stomach', 'normal']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'no', '150-200 lbs', 'head', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'yes', 'no', '100-150 lbs', 'chest', 'return later']
# choice:  return later
# val:  {'correlated_fields': [{'name': 'shortness_of_breath', 'correlated_category_values': {'yes': 0.6, 'no': 0.2}}]}
# row,  ['Under 18', 'female', 'Asian', 'yes', 'no', '150-200 lbs', 'limb', 'return later']
# choice:  normal
# val:  {'correlated_fields': [{'name': 'race', 'correlated_category_values': {'White': 0.75, 'Black or African American': 0.3}}]}
# row,  ['Over 60', 'male', 'White', 'no', 'yes', '100-150 lbs', 'head', 'normal']
# choice:  priority
# val:  {'freq': 0.1, 'correlated_fields': [{'name': 'gender', 'correlated_category_values': {'male': 0.75}}]}
# row,  ['18-34', 'male', 'White', 'yes', 'no', 'Over 300 lbs', 'chest', 'priority']
