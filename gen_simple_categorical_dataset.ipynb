# %%
import csv
import json
import os
import random

# %% [markdown]
# If you're using a JSON file, you can point to it in the code block below. Otherwise, use the second code block to fill out a dict that describes the dataset you're generating. Your data should look something like this:
# ```
# data_descriptor_json = {
#   "defaultLabelColumn": "recommendation", #the default label to be predicted
#   "fields": [
#     {
#       "id": "age", #whatever the field contains
#       "type": "categorical", #or continuous, or binary
#       "values": {
#         #if categorical or binary
#         "categories": [],
#         #if continuous:
#         "min": 0,
#         "max": 100
#       }
#     }
#    ]
# }
# ```

# %%
data_json_file = open('your_file.json')
data_descriptor_json = json.read(data_json_file)

# %%
data_descriptor_json = {
  "defaultLabelColumn": "decision",
  "fields": [
    {
      "id": "age",
      "type": "categorical",
      "values": {
        "categories": ["Under 18", "18-34", "35-60", "Over 60"]
      }
    },
    {
      "id": "gender",
      "type": "categorical",
      "values": {
        "categories": ["male", "female"]
      }
    },
    {
      "id": "race",
      "type": "categorical",
      "values": {
        "categories": ["White", "Black or African American", "Asian", "American Indian or Alaska Native", "Native Hawaiian or Pacific Islander"]
      }
    },
    {
      "id": "bleeding",
      "type": "categorical",
      "values": {
        "categories": ["yes", "no"]
      }
    },
    {
      "id": "shortness_of_breath",
      "type": "categorical",
      "values": {
        "categories": ["yes", "no"]
      }
    },
    {
      "id": "weight",
      "type": "categorical",
      "values": {
        "categories": ["under 100 lbs", "100-150 lbs", "150-200 lbs", "200-300 lbs", "Over 300 lbs"]
      }
    },
    {
      "id": "area_of_pain",
      "type": "categorical",
      "values": {
        "categories": ["head", "chest", "limb", "stomach"]
      }
    },
    {
      "id": "decision",
      "type": "categorical",
      "values": {
        "categories": ["priority", "normal", "return later"]
      }
    }
  ]
}

fields = data_descriptor_json['fields']
label = data_descriptor_json['defaultLabelColumn']

# %% [markdown]
# Here we set up our constants. Basically, we want to set up a relationship between potential categories and a label outcome.
# ```
# {
#  "defaultLabelColumn": "is_sick",
#  "fields": [
#      {
#          "id": "nose_status"
#          "type: "categorical"
#          "values": {
#          "categories": [
#          "runny", "bleeding", "dry", "exploded"
#          ]
#      },
#      {
#          "id": "is_sick"
#          "type: "categorical"
#          "values": {
#          "categories": [
#          "no", "maybe", "definitely", "extremely"
#          ]
#      },
#  }
# ```
#  And, as a rule, if a patient's nose is dry they're always fine but otherwise the worse symptoms they have the more likely they are to be sick, we can structure our correlation as follows, using values below 0.5 for negative correlation and above 0.5 for positive:
#
# ```
# correlation_values = {
#     #here we use the categories of outcome as keys:
#         "no": {
#             "freq": #how often this answer should occur
#             "correlated_fields": [{"name": "nose_status", "correlated_category_values": {"dry": 1, "exploded": 0}] # so if nose_status = dry, is_sick = "no, while if their nose has exploded they're definitely sick!
#         }
#      }
# ```

# %% [markdown]
# This block prints out a quick template for converting our values in order to set up our correlation relationships

# %%
label_values = []
for i in fields:
    if i['id'] == label:
        label_values = i['values']['categories']
        print("template_values = {")
        for k in i['values']['categories']:
            print('"%s": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},' % k)
        print("}}")
    else:
        print('field: ', i['id'])
        print('categories: ', i['values']['categories'])
# Out:
# field:  age
# categories:  ['Under 18', '18-34', '35-60', 'Over 60']
# field:  gender
# categories:  ['male', 'female']
# field:  race
# categories:  ['White', 'Black or African American', 'Asian', 'American Indian or Alaska Native', 'Native Hawaiian or Pacific Islander']
# field:  bleeding
# categories:  ['yes', 'no']
# field:  shortness_of_breath
# categories:  ['yes', 'no']
# field:  weight
# categories:  ['under 100 lbs', '100-150 lbs', '150-200 lbs', '200-300 lbs', 'Over 300 lbs']
# field:  area_of_pain
# categories:  ['head', 'chest', 'limb', 'stomach']
# template_values = {
# "priority": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},
# "normal": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},
# "return later": {"freq": 0,"correlated_fields": [{"name": "field_name", "correlated_category_values": {"feature": 0}}]},
# }}

# %%
correlation_values = {"priority": {"freq": 0.1, "correlated_fields": [{"name": "gender", "correlated_category_values": {"male": .75}}]},
"normal": {"correlated_fields": [{"name": "race", "correlated_category_values": {"White": .75, 'Black or African American': 0.3}}]},
"return later": {"correlated_fields": [{"name": "shortness_of_breath", "correlated_category_values": {"yes": .6, "no": .2}}]}
}

num_rows = 200 # the number of rows in our output dataset
outfile_name = 'medical_priority.csv' # the name of the file we're writing to, should end in '.csv'
print(json.dumps(correlation_values, indent=2))
# Out:
# {
#   "priority": {
#     "freq": 0.1,
#     "correlated_fields": [
#       {
#         "name": "gender",
#         "correlated_category_values": {
#           "male": 0.75
#         }
#       }
#     ]
#   },
#   "normal": {
#     "correlated_fields": [
#       {
#         "name": "race",
#         "correlated_category_values": {
#           "White": 0.75,
#           "Black or African American": 0.3
#         }
#       }
#     ]
#   },
#   "return later": {
#     "correlated_fields": [
#       {
#         "name": "shortness_of_breath",
#         "correlated_category_values": {
#           "yes": 0.6,
#           "no": 0.2
#         }
#       }
#     ]
#   }
# }

# %%
#write the file
with open(outfile_name, 'w') as outfile:
    writer = csv.writer(outfile, delimiter=',')
    headers = [field['id'] for field in data_descriptor_json['fields']]
    writer.writerow(headers)
    label_val_idx = headers.index(label)
    

        
    for i in range(num_rows):
        row = []
        #object to see how highly they're correlated with diff outcomes
        correlation_counter = {}
        negative_correlation_counter = {}
        for field in data_descriptor_json['fields']:
            field_name = field['id']
            if field_name == label:
                row.append('')
                continue
            values = field["values"]
            categories = values["categories"]
            random_num = random.random()
            random_choice = random.choice(categories)
            
            def check_frequency(choice, val, num, categories):
                if 'freq' in val and num > val['freq']:
                    new_choice = random.choice(categories)
                    new_val = correlation_values[choice]
                    print('new choice: ', new_choice)
                    return check_frequency(new_choice, new_val, num, categories)
                else:
                    return choice
            
            #check against correlation values and increment our relationship accordingly
            for key, value in correlation_values.items():
                for i in value["correlated_fields"]:
                    corr_vals = i['correlated_category_values']
                    if random_choice in corr_vals.keys():
                        if key not in correlation_counter or correlation_counter[key] < corr_vals[random_choice]:
                            if corr_vals[random_choice] > 0.5:
                                correlation_counter[key] = corr_vals[random_choice]
                        if key not in negative_correlation_counter or negative_correlation_counter[key] > corr_vals[random_choice]:
                            if corr_vals[random_choice] < 0.5:
                                negative_correlation_counter[key] = corr_vals[random_choice]
            row.append(random_choice)
        random_label = random.choice(label_values)
        random_number = random.random()
        decision = random_label
        for key, value in correlation_counter.items():
            if decision not in correlation_counter.keys():
                decision = key
            else:
                if correlation_counter[key] > correlation_counter[decision]:
                    decision = key
        trimmed_labels = label_values.copy()
        trimmed_labels.remove(decision)
        
        print('trimmed labels')
        print('initial decision', decision)
        print('random num', random_number)
        decision = check_frequency(decision, correlation_values[decision], random_num, label_values)
        print('final decision', decision)

        if decision in negative_correlation_counter and decision in correlation_counter:
            if 1 - negative_correlation_counter[decision] > correlation_counter[decision] and random_num < negative_correlation_counter[decision]:
                row[label_val_idx] = random.choice(trimmed_labels)
            else:
                if random_num < correlation_counter[decision]:
                    row[label_val_idx] = decision
                else:
                    row[label_val_idx] = random.choice(trimmed_labels)
        else:
            if decision in correlation_counter and random_num < correlation_counter[decision]:
                row[label_val_idx] = decision
            else:
                row[label_val_idx] = random.choice(trimmed_labels)


        print('row, ', row)
        
            
                    
                

                            
                        
      #  writer.writerow(row)
# Out:
# trimmed labels
# initial decision return later
# random num 0.3611845506462317
# final decision return later
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '100-150 lbs', 'chest', 'priority']
# trimmed labels
# initial decision return later
# random num 0.037873160068915945
# final decision return later
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '100-150 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.6356176722772499
# new choice:  priority
# new choice:  priority
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'Asian', 'yes', 'yes', '150-200 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.7425257472506803
# new choice:  priority
# new choice:  priority
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'yes', 'no', '150-200 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.8592776091560906
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['18-34', 'male', 'Black or African American', 'yes', 'yes', '100-150 lbs', 'head', 'return later']
# trimmed labels
# initial decision return later
# random num 0.13629037593017745
# final decision return later
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', 'under 100 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.23803671312593588
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', 'Over 300 lbs', 'limb', 'normal']
# trimmed labels
# initial decision normal
# random num 0.761149992585196
# final decision normal
# row,  ['35-60', 'female', 'White', 'no', 'no', 'under 100 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.8568458873729674
# new choice:  priority
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Over 60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '100-150 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision normal
# random num 0.04789961241803564
# final decision normal
# row,  ['Over 60', 'male', 'White', 'no', 'yes', '100-150 lbs', 'head', 'normal']
# trimmed labels
# initial decision return later
# random num 0.5057171629234775
# final decision return later
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '150-200 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.4180837799568372
# final decision return later
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'yes', 'no', '100-150 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.2536143875955861
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'Asian', 'no', 'no', '100-150 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.0040817656628521215
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'yes', 'Over 300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.49314271836873214
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '150-200 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.8064473139035251
# final decision return later
# row,  ['Under 18', 'female', 'Asian', 'yes', 'yes', '150-200 lbs', 'limb', 'return later']
# trimmed labels
# initial decision priority
# random num 0.6147010927577714
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['18-34', 'male', 'Black or African American', 'no', 'yes', 'under 100 lbs', 'limb', 'return later']
# trimmed labels
# initial decision return later
# random num 0.7844182747843097
# final decision return later
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '100-150 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision return later
# random num 0.6661135809406137
# final decision return later
# row,  ['18-34', 'female', 'Asian', 'no', 'yes', '100-150 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision normal
# random num 0.9985426163285973
# final decision normal
# row,  ['18-34', 'female', 'White', 'yes', 'no', 'under 100 lbs', 'limb', 'normal']
# trimmed labels
# initial decision normal
# random num 0.3573567606543212
# final decision normal
# row,  ['18-34', 'female', 'Asian', 'no', 'no', '150-200 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision priority
# random num 0.7280209831702342
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'yes', 'yes', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision return later
# random num 0.757229349797912
# final decision return later
# row,  ['Over 60', 'female', 'Black or African American', 'no', 'yes', '150-200 lbs', 'head', 'priority']
# trimmed labels
# initial decision priority
# random num 0.294009559256563
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['18-34', 'male', 'White', 'no', 'yes', '100-150 lbs', 'chest', 'priority']
# trimmed labels
# initial decision normal
# random num 0.9118401543461006
# final decision normal
# row,  ['Under 18', 'female', 'White', 'yes', 'no', '150-200 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.9324809568509227
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', 'Over 300 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.277446306995455
# final decision priority
# row,  ['Over 60', 'male', 'Black or African American', 'no', 'no', 'Over 300 lbs', 'head', 'priority']
# trimmed labels
# initial decision return later
# random num 0.06844930379570668
# final decision return later
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'Over 300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision normal
# random num 0.9877260125896107
# final decision normal
# row,  ['35-60', 'female', 'White', 'yes', 'no', '200-300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.6858089027424834
# final decision return later
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision return later
# random num 0.32474535225482326
# final decision return later
# row,  ['35-60', 'female', 'Black or African American', 'yes', 'no', 'Over 300 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision return later
# random num 0.10683505656955194
# final decision return later
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.27004159079950496
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'under 100 lbs', 'chest', 'normal']
# trimmed labels
# initial decision return later
# random num 0.47330606541959364
# final decision return later
# row,  ['35-60', 'female', 'Black or African American', 'yes', 'yes', '100-150 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.5564801553531684
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '150-200 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision normal
# random num 0.1649737266629847
# final decision normal
# row,  ['Under 18', 'female', 'White', 'yes', 'no', '100-150 lbs', 'chest', 'normal']
# trimmed labels
# initial decision return later
# random num 0.3188748037691992
# final decision return later
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', 'Over 300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision return later
# random num 0.24117359847968833
# final decision return later
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '100-150 lbs', 'chest', 'priority']
# trimmed labels
# initial decision priority
# random num 0.24030488647196402
# final decision priority
# row,  ['18-34', 'male', 'Asian', 'no', 'no', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.5935427985587681
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '150-200 lbs', 'chest', 'normal']
# trimmed labels
# initial decision normal
# random num 0.28625714115317347
# final decision normal
# row,  ['18-34', 'female', 'White', 'no', 'no', '150-200 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.8661986365315384
# final decision priority
# row,  ['18-34', 'male', 'White', 'no', 'no', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.3051430274924981
# final decision return later
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'under 100 lbs', 'head', 'return later']
# trimmed labels
# initial decision return later
# random num 0.3296478438438468
# final decision return later
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'yes', 'no', 'under 100 lbs', 'chest', 'priority']
# trimmed labels
# initial decision return later
# random num 0.4220177172693641
# final decision return later
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '100-150 lbs', 'head', 'priority']
# trimmed labels
# initial decision return later
# random num 0.10383485681708438
# final decision return later
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision normal
# random num 0.11947408967557949
# final decision normal
# row,  ['Over 60', 'male', 'White', 'yes', 'no', 'under 100 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.9241005776588374
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'yes', '150-200 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision priority
# random num 0.5933228662599409
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'no', 'no', '200-300 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.8039935068456142
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'Asian', 'yes', 'no', '200-300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.7538944130967997
# final decision return later
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'yes', 'no', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.6688790667945911
# final decision return later
# row,  ['35-60', 'female', 'Black or African American', 'yes', 'yes', '150-200 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.9485553762165495
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'no', 'under 100 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.6523858636722738
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'White', 'no', 'no', '150-200 lbs', 'chest', 'normal']
# trimmed labels
# initial decision return later
# random num 0.1760820700761837
# final decision return later
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', 'Over 300 lbs', 'limb', 'normal']
# trimmed labels
# initial decision return later
# random num 0.6896782532946208
# final decision return later
# row,  ['Under 18', 'female', 'Black or African American', 'yes', 'no', '200-300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision priority
# random num 0.2542410763383516
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Over 60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision normal
# random num 0.8020663093670853
# final decision normal
# row,  ['Under 18', 'female', 'White', 'no', 'yes', 'under 100 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.5287040419820102
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'Black or African American', 'no', 'yes', 'under 100 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.1531099529578288
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['18-34', 'male', 'Black or African American', 'yes', 'no', '200-300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision priority
# random num 0.5032260344968684
# new choice:  priority
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Over 60', 'male', 'White', 'no', 'yes', '150-200 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision normal
# random num 0.8483754729082941
# final decision normal
# row,  ['35-60', 'male', 'White', 'yes', 'yes', '100-150 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.6895969703794431
# new choice:  priority
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision normal
# random num 0.4592874811879609
# final decision normal
# row,  ['18-34', 'female', 'White', 'no', 'no', 'under 100 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.5399711610088928
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['18-34', 'male', 'Asian', 'no', 'no', 'under 100 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.42199972278471
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'yes', 'yes', 'Over 300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.7481268841147252
# new choice:  priority
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'White', 'no', 'yes', 'under 100 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.5851226601439148
# new choice:  priority
# new choice:  priority
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['Over 60', 'male', 'American Indian or Alaska Native', 'yes', 'yes', '150-200 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.3138043136492422
# final decision return later
# row,  ['Under 18', 'female', 'Asian', 'no', 'yes', 'under 100 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.6137375680334326
# final decision return later
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '200-300 lbs', 'head', 'return later']
# trimmed labels
# initial decision return later
# random num 0.38445484117416606
# final decision return later
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'yes', 'no', '200-300 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision return later
# random num 0.6212914787159753
# final decision return later
# row,  ['35-60', 'female', 'American Indian or Alaska Native', 'yes', 'no', '100-150 lbs', 'head', 'priority']
# trimmed labels
# initial decision priority
# random num 0.6478737992856682
# new choice:  priority
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'yes', 'yes', '200-300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.3173890812048664
# final decision return later
# row,  ['Under 18', 'female', 'Asian', 'no', 'yes', '100-150 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.5280847737360012
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['18-34', 'male', 'Asian', 'yes', 'no', 'under 100 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.8701134932106191
# new choice:  priority
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'Black or African American', 'no', 'no', 'Over 300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision normal
# random num 0.34378193994386885
# final decision normal
# row,  ['35-60', 'male', 'White', 'yes', 'yes', 'under 100 lbs', 'chest', 'priority']
# trimmed labels
# initial decision normal
# random num 0.061639557693023095
# final decision normal
# row,  ['35-60', 'female', 'White', 'no', 'yes', '100-150 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.5124668969412138
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'yes', 'Over 300 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision normal
# random num 0.04761550427546324
# final decision normal
# row,  ['Over 60', 'female', 'White', 'yes', 'yes', 'under 100 lbs', 'head', 'priority']
# trimmed labels
# initial decision priority
# random num 0.5344421775888468
# final decision priority
# row,  ['Over 60', 'male', 'White', 'yes', 'no', '150-200 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision return later
# random num 0.004267409756096074
# final decision return later
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', 'under 100 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.834556006796923
# new choice:  priority
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', '100-150 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.6117030859362653
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.6495963244932437
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['18-34', 'male', 'Asian', 'yes', 'no', '200-300 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.030384941648936348
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['18-34', 'male', 'Black or African American', 'no', 'no', '200-300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.30345878235984136
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['Over 60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.6621407954329337
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['18-34', 'male', 'American Indian or Alaska Native', 'no', 'no', '150-200 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.18626152887468506
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'Asian', 'yes', 'yes', 'Over 300 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision return later
# random num 0.7249952866459771
# final decision return later
# row,  ['Under 18', 'female', 'Black or African American', 'no', 'yes', '100-150 lbs', 'chest', 'normal']
# trimmed labels
# initial decision return later
# random num 0.48070843789359263
# final decision return later
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'yes', '100-150 lbs', 'limb', 'return later']
# trimmed labels
# initial decision return later
# random num 0.3842815329457584
# final decision return later
# row,  ['35-60', 'female', 'Asian', 'yes', 'yes', '100-150 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.20306751817030466
# final decision return later
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'yes', 'under 100 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.8483994325003867
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'yes', 'no', '200-300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.03168368557608958
# final decision return later
# row,  ['Under 18', 'female', 'Asian', 'no', 'no', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.7303324605042376
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'Asian', 'no', 'yes', 'under 100 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.9913762374551328
# new choice:  priority
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '200-300 lbs', 'chest', 'priority']
# trimmed labels
# initial decision priority
# random num 0.7080989715461625
# new choice:  priority
# new choice:  priority
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'American Indian or Alaska Native', 'yes', 'no', '200-300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.020645221401425107
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.11662362129787496
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'no', 'no', '150-200 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.5063911471711668
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['18-34', 'male', 'Black or African American', 'no', 'yes', 'Over 300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision return later
# random num 0.34882655729970113
# final decision return later
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'no', '150-200 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.4288276165566307
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', '100-150 lbs', 'limb', 'return later']
# trimmed labels
# initial decision normal
# random num 0.42518315549289776
# final decision normal
# row,  ['Under 18', 'female', 'White', 'no', 'yes', '100-150 lbs', 'chest', 'priority']
# trimmed labels
# initial decision priority
# random num 0.6894406799524097
# final decision priority
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'under 100 lbs', 'chest', 'priority']
# trimmed labels
# initial decision return later
# random num 0.7514966343531975
# final decision return later
# row,  ['35-60', 'female', 'Asian', 'yes', 'no', 'under 100 lbs', 'head', 'return later']
# trimmed labels
# initial decision return later
# random num 0.08092796761424381
# final decision return later
# row,  ['35-60', 'female', 'Asian', 'no', 'yes', '200-300 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.6311090300485609
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', 'under 100 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.7588776044649254
# new choice:  priority
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'Asian', 'yes', 'no', '200-300 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision return later
# random num 0.7878077449571791
# final decision return later
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '150-200 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.9306942142443195
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['18-34', 'male', 'American Indian or Alaska Native', 'yes', 'yes', 'Over 300 lbs', 'chest', 'normal']
# trimmed labels
# initial decision return later
# random num 0.9115248428192158
# final decision return later
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'yes', 'no', '150-200 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision return later
# random num 0.44823325484334464
# final decision return later
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'under 100 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision priority
# random num 0.9741279126845265
# new choice:  priority
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'Black or African American', 'yes', 'no', '150-200 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.5664661063751659
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Under 18', 'male', 'White', 'yes', 'yes', 'under 100 lbs', 'limb', 'return later']
# trimmed labels
# initial decision return later
# random num 0.24502830215970695
# final decision return later
# row,  ['35-60', 'female', 'American Indian or Alaska Native', 'yes', 'no', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision return later
# random num 0.5961936484769462
# final decision return later
# row,  ['Under 18', 'female', 'Asian', 'no', 'yes', 'Over 300 lbs', 'head', 'priority']
# trimmed labels
# initial decision return later
# random num 0.11611824276156535
# final decision return later
# row,  ['35-60', 'female', 'Asian', 'no', 'yes', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.22377746626958328
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', '200-300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.6479511788204301
# final decision return later
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'no', '100-150 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.3367572034849442
# new choice:  priority
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Over 60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'no', '100-150 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision normal
# random num 0.033887839756396754
# final decision normal
# row,  ['18-34', 'female', 'White', 'yes', 'no', 'under 100 lbs', 'chest', 'normal']
# trimmed labels
# initial decision priority
# random num 0.5402838147806919
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['18-34', 'male', 'Asian', 'yes', 'yes', 'Over 300 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision priority
# random num 0.8414116254027314
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Over 60', 'male', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', 'under 100 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.018216613729234332
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'Black or African American', 'yes', 'no', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.04917692164899967
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Over 60', 'male', 'Black or African American', 'no', 'yes', '200-300 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision priority
# random num 0.6499539160500565
# new choice:  priority
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'Black or African American', 'yes', 'no', 'Over 300 lbs', 'head', 'priority']
# trimmed labels
# initial decision normal
# random num 0.20499335898750237
# final decision normal
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '150-200 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.7372400759157637
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'yes', 'no', '200-300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision return later
# random num 0.3366009967621978
# final decision return later
# row,  ['Under 18', 'female', 'Asian', 'yes', 'yes', 'under 100 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision normal
# random num 0.865771180090815
# final decision normal
# row,  ['Over 60', 'female', 'Black or African American', 'no', 'no', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision normal
# random num 0.053114133113972284
# final decision normal
# row,  ['35-60', 'female', 'White', 'no', 'no', '150-200 lbs', 'limb', 'return later']
# trimmed labels
# initial decision priority
# random num 0.9304108365287881
# final decision priority
# row,  ['35-60', 'male', 'Black or African American', 'no', 'no', 'under 100 lbs', 'head', 'priority']
# trimmed labels
# initial decision normal
# random num 0.6271944858656051
# final decision normal
# row,  ['35-60', 'female', 'White', 'no', 'no', '150-200 lbs', 'head', 'priority']
# trimmed labels
# initial decision return later
# random num 0.6572163314508841
# final decision return later
# row,  ['Under 18', 'female', 'Black or African American', 'yes', 'no', '150-200 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.8051603479799015
# final decision return later
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'yes', '200-300 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.8355511523682043
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['Over 60', 'male', 'Black or African American', 'yes', 'yes', '100-150 lbs', 'chest', 'priority']
# trimmed labels
# initial decision priority
# random num 0.059099928698736925
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'Black or African American', 'no', 'no', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision priority
# random num 0.8348988136213102
# final decision priority
# row,  ['18-34', 'male', 'Asian', 'yes', 'no', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision return later
# random num 0.8940768320587611
# final decision return later
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'yes', 'Over 300 lbs', 'head', 'return later']
# trimmed labels
# initial decision return later
# random num 0.9588364117016943
# final decision return later
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'Over 300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.5156729418916547
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'American Indian or Alaska Native', 'no', 'yes', 'Over 300 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.3111978704456191
# final decision return later
# row,  ['35-60', 'female', 'American Indian or Alaska Native', 'yes', 'yes', 'under 100 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision return later
# random num 0.683751286533733
# final decision return later
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '150-200 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision normal
# random num 0.5697526200846466
# final decision normal
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '200-300 lbs', 'head', 'return later']
# trimmed labels
# initial decision normal
# random num 0.9842127291137298
# final decision normal
# row,  ['Over 60', 'male', 'White', 'yes', 'yes', 'under 100 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.3769430264236494
# new choice:  priority
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'Black or African American', 'yes', 'no', 'Over 300 lbs', 'head', 'return later']
# trimmed labels
# initial decision return later
# random num 0.7374227753168224
# final decision return later
# row,  ['35-60', 'female', 'Black or African American', 'yes', 'no', '100-150 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.6111592048872286
# final decision return later
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'no', 'yes', '100-150 lbs', 'chest', 'priority']
# trimmed labels
# initial decision normal
# random num 0.07806959676579295
# final decision normal
# row,  ['Under 18', 'female', 'White', 'yes', 'yes', '150-200 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.15023449374350706
# new choice:  priority
# new choice:  priority
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['35-60', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.581689398095457
# new choice:  priority
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'Black or African American', 'yes', 'yes', '100-150 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.4702690317996594
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['35-60', 'male', 'Asian', 'yes', 'yes', '100-150 lbs', 'chest', 'normal']
# trimmed labels
# initial decision normal
# random num 0.7763118510654438
# final decision normal
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'no', '200-300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision normal
# random num 0.5539975691921109
# final decision normal
# row,  ['18-34', 'female', 'White', 'no', 'no', '200-300 lbs', 'head', 'normal']
# trimmed labels
# initial decision priority
# random num 0.02133381059887629
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'Asian', 'yes', 'yes', 'under 100 lbs', 'limb', 'normal']
# trimmed labels
# initial decision priority
# random num 0.23751943788010843
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['18-34', 'male', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '100-150 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision normal
# random num 0.5783074959058512
# final decision normal
# row,  ['Under 18', 'female', 'White', 'no', 'no', '200-300 lbs', 'limb', 'normal']
# trimmed labels
# initial decision return later
# random num 0.5737485294763889
# final decision return later
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', 'Over 300 lbs', 'chest', 'return later']
# trimmed labels
# initial decision normal
# random num 0.25963063032135025
# final decision normal
# row,  ['Over 60', 'female', 'White', 'yes', 'no', '100-150 lbs', 'chest', 'normal']
# trimmed labels
# initial decision return later
# random num 0.5053276584269359
# final decision return later
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '200-300 lbs', 'head', 'priority']
# trimmed labels
# initial decision return later
# random num 0.14106578092489963
# final decision return later
# row,  ['Under 18', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'Over 300 lbs', 'limb', 'return later']
# trimmed labels
# initial decision return later
# random num 0.30839168178879683
# final decision return later
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'under 100 lbs', 'limb', 'normal']
# trimmed labels
# initial decision normal
# random num 0.8668297009278364
# final decision normal
# row,  ['35-60', 'female', 'White', 'no', 'no', 'Over 300 lbs', 'head', 'normal']
# trimmed labels
# initial decision return later
# random num 0.5524898746840234
# final decision return later
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '200-300 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.7314968675214256
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'Asian', 'no', 'yes', '100-150 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.7975346396630041
# final decision return later
# row,  ['18-34', 'female', 'American Indian or Alaska Native', 'no', 'yes', '200-300 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.21727684626993815
# new choice:  priority
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['Over 60', 'male', 'White', 'no', 'no', '200-300 lbs', 'limb', 'normal']
# trimmed labels
# initial decision return later
# random num 0.5029656689100468
# final decision return later
# row,  ['Over 60', 'female', 'American Indian or Alaska Native', 'yes', 'yes', '100-150 lbs', 'limb', 'return later']
# trimmed labels
# initial decision priority
# random num 0.39344269185825165
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['35-60', 'male', 'Asian', 'no', 'yes', 'under 100 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.3108470552663092
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['35-60', 'male', 'Asian', 'yes', 'no', '200-300 lbs', 'chest', 'normal']
# trimmed labels
# initial decision return later
# random num 0.597496115175027
# final decision return later
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '150-200 lbs', 'chest', 'return later']
# trimmed labels
# initial decision priority
# random num 0.1955699430918495
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['18-34', 'male', 'White', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# trimmed labels
# initial decision return later
# random num 0.43833353838678646
# final decision return later
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '100-150 lbs', 'limb', 'priority']
# trimmed labels
# initial decision normal
# random num 0.23434026281090548
# final decision normal
# row,  ['Over 60', 'female', 'White', 'no', 'yes', '200-300 lbs', 'chest', 'priority']
# trimmed labels
# initial decision priority
# random num 0.11420386093853385
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'White', 'no', 'yes', '100-150 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision priority
# random num 0.6745909545802281
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['18-34', 'female', 'Black or African American', 'no', 'no', '200-300 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision return later
# random num 0.19421747504691178
# final decision return later
# row,  ['Over 60', 'female', 'Asian', 'yes', 'yes', '200-300 lbs', 'chest', 'priority']
# trimmed labels
# initial decision normal
# random num 0.9683122802982232
# final decision normal
# row,  ['18-34', 'female', 'White', 'yes', 'yes', '100-150 lbs', 'chest', 'return later']
# trimmed labels
# initial decision return later
# random num 0.5578132590420798
# final decision return later
# row,  ['Over 60', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', 'under 100 lbs', 'head', 'normal']
# trimmed labels
# initial decision normal
# random num 0.2582427257619144
# final decision normal
# row,  ['35-60', 'female', 'White', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.4224223009574962
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  priority
# new choice:  normal
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'White', 'yes', 'no', '150-200 lbs', 'limb', 'return later']
# trimmed labels
# initial decision normal
# random num 0.9198694163974542
# final decision normal
# row,  ['35-60', 'female', 'White', 'yes', 'no', '150-200 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision return later
# random num 0.9208150137311809
# final decision return later
# row,  ['35-60', 'female', 'Native Hawaiian or Pacific Islander', 'yes', 'no', '100-150 lbs', 'limb', 'return later']
# trimmed labels
# initial decision priority
# random num 0.11270879145376489
# new choice:  priority
# new choice:  priority
# new choice:  normal
# new choice:  normal
# final decision normal
# row,  ['Over 60', 'male', 'Asian', 'no', 'yes', '150-200 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.258842415007161
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'no', 'no', 'under 100 lbs', 'head', 'normal']
# trimmed labels
# initial decision return later
# random num 0.6940555945469494
# final decision return later
# row,  ['Under 18', 'female', 'American Indian or Alaska Native', 'yes', 'no', '100-150 lbs', 'stomach', 'return later']
# trimmed labels
# initial decision priority
# random num 0.028224660334007612
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['Under 18', 'male', 'Asian', 'yes', 'no', 'Over 300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.1331057927586332
# new choice:  priority
# new choice:  return later
# new choice:  return later
# final decision return later
# row,  ['Over 60', 'male', 'Asian', 'no', 'yes', 'Over 300 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.11643282841606295
# new choice:  normal
# new choice:  priority
# final decision priority
# row,  ['Over 60', 'male', 'White', 'no', 'yes', 'Over 300 lbs', 'head', 'priority']
# trimmed labels
# initial decision normal
# random num 0.15937294010331182
# final decision normal
# row,  ['35-60', 'male', 'White', 'no', 'no', 'under 100 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.8091966642993351
# final decision priority
# row,  ['Over 60', 'male', 'Black or African American', 'no', 'yes', 'Over 300 lbs', 'head', 'priority']
# trimmed labels
# initial decision priority
# random num 0.6993881218440617
# new choice:  return later
# new choice:  priority
# final decision priority
# row,  ['35-60', 'male', 'White', 'no', 'yes', 'under 100 lbs', 'limb', 'priority']
# trimmed labels
# initial decision return later
# random num 0.2844010598715506
# final decision return later
# row,  ['18-34', 'female', 'Native Hawaiian or Pacific Islander', 'no', 'yes', '150-200 lbs', 'limb', 'normal']
# trimmed labels
# initial decision return later
# random num 0.9344250421406969
# final decision return later
# row,  ['18-34', 'female', 'Black or African American', 'yes', 'yes', 'under 100 lbs', 'limb', 'normal']
# trimmed labels
# initial decision normal
# random num 0.2715788292450464
# final decision normal
# row,  ['Under 18', 'female', 'White', 'no', 'yes', '100-150 lbs', 'head', 'return later']
# trimmed labels
# initial decision priority
# random num 0.0011125918791337064
# final decision priority
# row,  ['Over 60', 'male', 'Black or African American', 'no', 'yes', '200-300 lbs', 'stomach', 'priority']
# trimmed labels
# initial decision priority
# random num 0.34784201921894664
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['Under 18', 'male', 'American Indian or Alaska Native', 'no', 'no', 'Over 300 lbs', 'limb', 'normal']
# trimmed labels
# initial decision normal
# random num 0.31153189242826307
# final decision normal
# row,  ['18-34', 'male', 'White', 'no', 'yes', 'under 100 lbs', 'stomach', 'normal']
# trimmed labels
# initial decision priority
# random num 0.6743224172034887
# new choice:  return later
# new choice:  normal
# final decision normal
# row,  ['35-60', 'male', 'Asian', 'yes', 'yes', 'Over 300 lbs', 'head', 'return later']
