# %%
import csv
import json
import os
import random

# %% [markdown]
# Fill out a dict that describes the dataset you're generating. Your data should look something like this:
# ```
# data_descriptor_json = {
#   "defaultLabelColumn": "recommendation", #the default label to be predicted
#   "fields": [
#     {
#       "id": "age", #whatever the field contains
#       "type": "categorical", #or continuous, or binary
#       "values": {
#         #if categorical or binary
#         "categories": [],
#         #if continuous:
#         "min": 0,
#         "max": 100
#       }
#     }
#    ]
# }
# ```

# %%
data_descriptor_json = {
  "defaultLabelColumn": "Liked", #the default label to be predicted
  "fields": [
    {
      "id": "Pepperoni", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
      }
    },
    {
      "id": "Extra Cheese", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
    },
    {
      "id": "Broccoli", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categori cal or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
    },
    {
      "id": "Olives", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
    },
    {
      "id": "Sausage", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
            },
         {
      "id": "Anchovies", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
      }
    },
    {
      "id": "Fried Chicken", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
    },
    {
      "id": "Peppers", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categori cal or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
    },
    {
      "id": "Ham", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
    },
    {
      "id": "Bacon", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
            },
        {
      "id": "Liked", #whatever the field contains
      "type": "categorical", #or continuous, or binary
      "values": {
        #if categorical or binary
        "categories": ["Yes", "No"],
        #if countinuous:
        "min": 0,
        "max": 100
      }
    }
    ]
      
}

# %% [markdown]
# Here we set up our constants. Add more correlation values as needed - the idea is that we'll assign a single correlation value to each combination of features/labels that we want in a dataset. The correlation value is a decimal between 0 and 1. If all features should have the same correlation to the designated output label, you can just set the "values" object to contain one key, "all", with that correlation value. You can also use "all" if a large number of columns should have the same result. For negative correlations, put in a number below 0.5, and for no correlation, use 0.

# %%
correlation_values = {"label": "Liked", "values": {"Pepperoni": 0.9, "Anchovies": 0.2, "Broccoli": 0.7, "Bacon": 0.6, "Pineapple": 0.3,  "all": 0}}
num_rows = 100
outfile_name = 'pizza_toppings_toy.csv' # the name of the file we're writing to: "my_file.csv"

# %%
#write the file
with open(outfile_name, 'w') as outfile:
    writer = csv.writer(outfile, delimiter=',')
    writer.writerow([field['id'] for field in data_descriptor_json['fields']])
    for i in range(num_rows):
        row = []
        label_val = random.randrange(2)
        for field in data_descriptor_json['fields']:
            if field['id'] == correlation_values['label']:
                row.append(field['values']['categories'][label_val])
                continue
            random_num = random.random()
            #FIXME this is ugly
            correlation_value = correlation_values['values'][field['id']] if field['id'] in correlation_values['values'] else random.random()
            if "all" in correlation_values['values'] and not field['id'] in correlation_values['values']:
                correlation_value = correlation_values['values']['all']
            if random_num < correlation_value:
                row.append(field['values']['categories'][label_val])
            elif correlation_value > 0:
                if label_val > 0:
                    row.append(field['values']['categories'][0])
                else:
                    row.append(field['values']['categories'][1])
            else:
                row.append(field['values']['categories'][random.randrange(2)])
        writer.writerow(row)
# Out:
#   File "<ipython-input-31-5d51d7c0c939>", line 25
#     row.append(field['values']['categories'][random.randrange(2)])
#       ^
# IndentationError: expected an indented block
